# %% [markdown]
# # Práctica: Comparación de modelos de regresión
#
# **Materia:** Tópicos de Big Data
# **Tema:** Introducción al aprendizaje supervisado mediante modelos de regresión
# **Herramientas:** Python · Jupyter Notebook · Pandas · NumPy · Matplotlib · Scikit-learn
#
# ---
#
# ## 1. Objetivo
#
# Construir diferentes modelos de aprendizaje supervisado para realizar **proyecciones del número de nacimientos y defunciones** de un país, utilizando datos históricos.
#
# Durante la práctica se implementarán y compararán visualmente tres modelos:
#
# 1. Regresión lineal
# 2. Regresión polinomial
# 3. Random Forest Regressor
#
# Al finalizar, podrás observar cómo **diferentes modelos generan predicciones diferentes utilizando exactamente los mismos datos**.
#
# > **Nota:** En esta práctica **no** se realizará todavía la evaluación formal de los modelos. La evaluación mediante métricas se realizará en la siguiente sesión.
#
# ---
#
# ## 2. Dataset
#
# Utilizaremos información de **Our World in Data (OWID)** sobre nacimientos y defunciones, que incluye datos históricos y proyecciones hasta el año 2100.
#
# Fuente: *Our World in Data – Births and deaths projected to 2100* (basado en las estimaciones y proyecciones de la ONU).
#
# El dataset contiene información por **país (o región) y año**.

# %% [markdown]
# # PARTE 1. Importar las bibliotecas
#
# En esta práctica utilizaremos:
#
# * **Pandas** para trabajar con el dataset.
# * **NumPy** para trabajar con arreglos y preparar datos.
# * **Matplotlib** para visualizar los datos y las predicciones.
# * **Scikit-learn** para construir los modelos de Machine Learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # PARTE 2. Cargar el dataset
#
# ## 3. Cargar los datos
#
# Leemos el archivo CSV directamente desde la página de OWID.
#
# > **Si no hay internet (o la descarga falla):** descarga el CSV desde la URL de la celda siguiente, guárdalo en la misma carpeta que este notebook con el nombre `births-and-deaths-projected-to-2100.csv` y vuelve a ejecutar la celda. El código lo detecta automáticamente.

# %%
url = "https://ourworldindata.org/grapher/births-and-deaths-projected-to-2100.csv?v=1&csvType=full&useColumnShortNames=true"

try:
    df = pd.read_csv(
        url,
        storage_options={
            "User-Agent": "Our World In Data data fetch/1.0"
        }
    )
except Exception as error:
    print("No fue posible descargar el archivo desde internet:", error)
    print("Se utilizará el archivo local 'births-and-deaths-projected-to-2100.csv'")
    df = pd.read_csv("births-and-deaths-projected-to-2100.csv")

df.head()
# Out:
#         entity code  year  deaths__sex_all__age_all__variant_estimates  \
# 0  Afghanistan  AFG  1950                                     290972.0
# 1  Afghanistan  AFG  1951                                     288752.0
# 2  Afghanistan  AFG  1952                                     288059.0
# 3  Afghanistan  AFG  1953                                     287712.0
# 4  Afghanistan  AFG  1954                                     289189.0
#
#    deaths__sex_all__age_all__variant_medium__projected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    births__sex_all__age_all__variant_estimates  \
# 0                                     383985.0
# 1                                     391002.0
# 2                                     397663.0
# ...

# %% [markdown]
# ## 4. Explorar el dataset
#
# Observemos la estructura del `DataFrame`.

# %%
print("Dimensiones (filas, columnas):", df.shape)
print()
print("Columnas:")
for columna in df.columns:
    print("  -", columna)
# Out:
# Dimensiones (filas, columnas): (39562, 7)
#
# Columnas:
#   - entity
#   - code
#   - year
#   - deaths__sex_all__age_all__variant_estimates
#   - deaths__sex_all__age_all__variant_medium__projected
#   - births__sex_all__age_all__variant_estimates
#   - births__sex_all__age_all__variant_medium__projected

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39562 entries, 0 to 39561
# Data columns (total 7 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   entity                                               39562 non-null  str
#  1   code                                                 38354 non-null  str
#  2   year                                                 39562 non-null  int64
#  3   deaths__sex_all__age_all__variant_estimates          18944 non-null  float64
#  4   deaths__sex_all__age_all__variant_medium__projected  19712 non-null  float64
#  5   births__sex_all__age_all__variant_estimates          19166 non-null  float64
#  6   births__sex_all__age_all__variant_medium__projected  19943 non-null  float64
# dtypes: float64(4), int64(1), str(2)
# memory usage: 2.1 MB

# %%
df.head(10)
# Out:
#         entity code  year  deaths__sex_all__age_all__variant_estimates  \
# 0  Afghanistan  AFG  1950                                     290972.0
# 1  Afghanistan  AFG  1951                                     288752.0
# 2  Afghanistan  AFG  1952                                     288059.0
# 3  Afghanistan  AFG  1953                                     287712.0
# 4  Afghanistan  AFG  1954                                     289189.0
# 5  Afghanistan  AFG  1955                                     286725.0
# 6  Afghanistan  AFG  1956                                     286654.0
# 7  Afghanistan  AFG  1957                                     286114.0
# 8  Afghanistan  AFG  1958                                     285911.0
# 9  Afghanistan  AFG  1959                                     285500.0
#
#    deaths__sex_all__age_all__variant_medium__projected  \
# 0                                                NaN
# 1                                                NaN
# ...

# %% [markdown]
# Revisemos las entidades disponibles:

# %%
print("Número de entidades:", df["entity"].nunique())
df["entity"].unique()
# Out:
# Número de entidades: 262
# <StringArray>
# [      'Afghanistan',            'Africa',       'Africa (UN)',
#            'Albania',           'Algeria',    'American Samoa',
#      'Americas (UN)',           'Andorra',            'Angola',
#           'Anguilla',
#  ...
#            'Vanuatu',           'Vatican',         'Venezuela',
#            'Vietnam', 'Wallis and Futuna',    'Western Sahara',
#              'World',             'Yemen',            'Zambia',
#           'Zimbabwe']
# Length: 262, dtype: str

# %% [markdown]
# ### Pregunta
#
# **¿Cuál es la unidad de observación de cada fila del dataset?**
#
# *Son los paises o entidades en un año especifico.*

# %% [markdown]
# ## 5. Preparar los nombres de las columnas
#
# Al explorar el dataset notamos dos cosas:
#
# 1. Los nombres de las columnas son largos y difíciles de escribir.
# 2. Los **datos históricos** (`..._variant_estimates`) y las **proyecciones de la ONU** (`..._variant_medium__projected`) vienen en **columnas separadas**. Cuando una fila es histórica, la columna de proyección está vacía (`NaN`), y viceversa.
#
# Vamos a renombrar las columnas y a crear dos columnas unificadas, `births` y `deaths`, que contengan el dato histórico cuando existe y la proyección de OWID cuando no.

# %%
df = df.rename(columns={
    "entity": "Entity",
    "code": "Code",
    "year": "Year",
    "births__sex_all__age_all__variant_estimates": "births_estimates",
    "births__sex_all__age_all__variant_medium__projected": "births_projected",
    "deaths__sex_all__age_all__variant_estimates": "deaths_estimates",
    "deaths__sex_all__age_all__variant_medium__projected": "deaths_projected",
})


df.head()
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
# 3  Afghanistan  AFG  1953          287712.0               NaN
# 4  Afghanistan  AFG  1954          289189.0               NaN
#
#    births_estimates  births_projected
# 0          383985.0               NaN
# 1          391002.0               NaN
# 2          397663.0               NaN
# 3          404666.0               NaN
# 4          410428.0               NaN

# %%
df_inicial = df.copy()
df_inicial.head(3)
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
#
#    births_estimates  births_projected
# 0          383985.0               NaN
# 1          391002.0               NaN
# 2          397663.0               NaN

# %%
# Columna unificada: dato histórico si existe; si no, la proyección de OWID
df["births"] = df["births_estimates"].fillna(df["births_projected"])
df["deaths"] = df["deaths_estimates"].fillna(df["deaths_projected"])
df.head()
# Out:
#         Entity Code  Year  deaths_estimates  deaths_projected  \
# 0  Afghanistan  AFG  1950          290972.0               NaN
# 1  Afghanistan  AFG  1951          288752.0               NaN
# 2  Afghanistan  AFG  1952          288059.0               NaN
# 3  Afghanistan  AFG  1953          287712.0               NaN
# 4  Afghanistan  AFG  1954          289189.0               NaN
#
#    births_estimates  births_projected    births    deaths
# 0          383985.0               NaN  383985.0  290972.0
# 1          391002.0               NaN  391002.0  288752.0
# 2          397663.0               NaN  397663.0  288059.0
# 3          404666.0               NaN  404666.0  287712.0
# 4          410428.0               NaN  410428.0  289189.0

# %% [markdown]
# # PARTE 3. Seleccionar un país
#
# ## 6. Seleccionar México
#
# Para esta práctica utilizaremos México.

# %%
pais = "Mexico"

df_mexico = df[df["Entity"] == pais]

df_mexico.head()
# Out:
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22801  Mexico  MEX  1950          596771.0               NaN
# 22802  Mexico  MEX  1951          588791.0               NaN
# 22803  Mexico  MEX  1952          582415.0               NaN
# 22804  Mexico  MEX  1953          565876.0               NaN
# 22805  Mexico  MEX  1954          552321.0               NaN
#
#        births_estimates  births_projected     births    deaths
# 22801         1358501.0               NaN  1358501.0  596771.0
# 22802         1392106.0               NaN  1392106.0  588791.0
# 22803         1423352.0               NaN  1423352.0  582415.0
# 22804         1454762.0               NaN  1454762.0  565876.0
# 22805         1488719.0               NaN  1488719.0  552321.0

# %%
print("Rango de años:", df_mexico["Year"].min(), "-", df_mexico["Year"].max())
print("Número de filas:", df_mexico.shape[0])
# Out:
# Rango de años: 1950 - 2100
# Número de filas: 151

# %% [markdown]
# ## 7. Revisar las variables disponibles
#
# Identifica las columnas correspondientes a: **año**, **nacimientos** y **defunciones**.

# %%
df_mexico.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'deaths_estimates', 'deaths_projected',
#        'births_estimates', 'births_projected', 'births', 'deaths'],
#       dtype='str')

# %% [markdown]
# Para esta práctica utilizaremos:
#
# ```text
# Year
# births
# deaths
# ```

# %% [markdown]
# # PARTE 4. Explorar visualmente los datos
#
# ## 8. Nacimientos a través del tiempo

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df_mexico["Year"],
    df_mexico["births"]
)

plt.title("Nacimientos en México")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.grid()
plt.show()

# %% [markdown]
# ## 9. Defunciones a través del tiempo

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df_mexico["Year"],
    df_mexico["deaths"]
)

plt.title("Defunciones en México")
plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.grid()
plt.show()

# %% [markdown]
# ### Preguntas de observación
#
# 1. ¿Los nacimientos presentan una tendencia constante?
# 2. ¿Las defunciones presentan una tendencia constante?
# 3. ¿Las dos variables parecen seguir el mismo comportamiento?
# 4. ¿Observas cambios en la tendencia a través del tiempo?
#
# *1- No, se puede observar que los nacimientos estaban en aumento y recientemente los mismos sufrieron de una caída notoria.*
# *2- Si, las defunciones se han mantenido en aumento con el paso de los años, mostrando un pico considerable en el año 2020 mismo que coincide con el transcurso de la pandemia.*
# *3- No, mientras las defunciones siguen en aumento, los nacimientos comenzaron una caída a pesar de haber estado previamente en aumento.*
# *4- En ambos hay cambios considerables a través del tiempo, por ejemplo, los nacimientos presentaron un punto máximo después de haber estado en aumento para luego presentar una caída considerable, mientras que las defuciones unicamente mostro una variacion cuando llego la pandemia.*

# %% [markdown]
# # PARTE 5. Separar datos históricos y proyectados
#
# ## 10. Identificar el punto de separación
#
# El dataset contiene **datos históricos** y **proyecciones**. Antes de separarlos, verifiquemos dónde termina uno y empieza el otro:

# %%
ultimo_historico = df_mexico.loc[df_mexico["births_estimates"].notna(), "Year"].max()
primera_proyeccion = df_mexico.loc[df_mexico["births_projected"].notna(), "Year"].min()

print("Último año con dato histórico:", ultimo_historico)
print("Primer año con proyección de OWID:", primera_proyeccion)
# Out:
# Último año con dato histórico: 2023
# Primer año con proyección de OWID: 2024

# %% [markdown]
# Para esta práctica utilizaremos como punto de separación el **año 2023**. Creamos dos `DataFrames`:

# %%
df_historico = df_mexico[
    df_mexico["Year"] <= 2023
]

df_proyectado = df_mexico[
    df_mexico["Year"] > 2023
]

print(df_historico.head(3))
print(df_proyectado.head(3))
# Out:
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22801  Mexico  MEX  1950          596771.0               NaN
# 22802  Mexico  MEX  1951          588791.0               NaN
# 22803  Mexico  MEX  1952          582415.0               NaN
#
#        births_estimates  births_projected     births    deaths
# 22801         1358501.0               NaN  1358501.0  596771.0
# 22802         1392106.0               NaN  1392106.0  588791.0
# 22803         1423352.0               NaN  1423352.0  582415.0
#        Entity Code  Year  deaths_estimates  deaths_projected  \
# 22875  Mexico  MEX  2024               NaN          813823.0
# 22876  Mexico  MEX  2025               NaN          829063.0
# 22877  Mexico  MEX  2026               NaN          844431.0
#
#        births_estimates  births_projected     births    deaths
# 22875               NaN         2023623.0  2023623.0  813823.0
# 22876               NaN         2003673.0  2003673.0  829063.0
# ...

# %%
print("Histórico  ->", df_historico.shape, "| años:", df_historico["Year"].min(), "a", df_historico["Year"].max())
print("Proyectado ->", df_proyectado.shape, "| años:", df_proyectado["Year"].min(), "a", df_proyectado["Year"].max())
# Out:
# Histórico  -> (74, 9) | años: 1950 a 2023
# Proyectado -> (77, 9) | años: 2024 a 2100

# %% [markdown]
# Comprobemos que no haya valores faltantes en las variables que vamos a utilizar para entrenar:

# %%
df_historico[["Year", "births", "deaths"]].isna().sum()
# Out:
# Year      0
# births    0
# deaths    0
# dtype: int64

# %% [markdown]
# # PARTE 6. Preparar las variables para Machine Learning
#
# ## 11. Definir X e y
#
# Para nuestro primer modelo utilizaremos:
#
# * **X:** año → la **variable predictora**
# * **y:** número de nacimientos → la **variable objetivo**

# %%
X = df_historico[["Year"]]
y_nacimientos = df_historico["births"]

# %%
X.head()
# Out:
#        Year
# 22801  1950
# 22802  1951
# 22803  1952
# 22804  1953
# 22805  1954

# %%
y_nacimientos.head()
# Out:
# 22801    1358501.0
# 22802    1392106.0
# 22803    1423352.0
# 22804    1454762.0
# 22805    1488719.0
# Name: births, dtype: float64

# %% [markdown]
# ## 12. Convertir los datos a NumPy
#
# Obtenemos los valores como arreglos de NumPy:

# %%
X_numpy = X.to_numpy()
y_numpy = y_nacimientos.to_numpy()

print("X_numpy.shape:", X_numpy.shape)
print("y_numpy.shape:", y_numpy.shape)
# Out:
# X_numpy.shape: (74, 1)
# y_numpy.shape: (74,)

# %%
type(X_numpy), type(y_numpy)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# ### Observación
#
# Scikit-learn espera normalmente que las variables predictoras tengan la forma:
#
# ```text
# (número de observaciones, número de variables)
# ```
# Es decir, que scikit-learn interpreta X como una tabla de datos.
#
# Por eso `X` tiene **dos dimensiones**, mientras que `y` tiene una sola.
#
# En nuestro ejemplo tenemos:
#
# 74 observaciones (registros).
#
# 1 variable predictora: año (estas son las caracteristicas o atributos usadas para la predicción).
#
# 1 variable objetivo: nacimientos (valor que deseamos predecir).

# %% [markdown]
# # PARTE 7. Modelo 1 – Regresión lineal
#
# ## 13. Crear el modelo

# %%
modelo_lineal = LinearRegression()

# %% [markdown]
# ## 14. Entrenar el modelo
#
# Utilizamos los datos históricos para entrenar el modelo.

# %%
modelo_lineal.fit(X, y_nacimientos)
# Out:
# LinearRegression()

# %% [markdown]
# Una regresión lineal aprende una recta `y = a·x + b`. Veamos qué valores aprendió:

# %%
print("Pendiente (a):", modelo_lineal.coef_[0])
print("Intercepto (b):", modelo_lineal.intercept_)
# Out:
# Pendiente (a): 8510.803983709739
# Intercepto (b): -14733373.127152909

# %% [markdown]
# ## 15. Realizar predicciones
#
# Utilizamos el modelo para estimar los nacimientos correspondientes a los **años históricos**.

# %%
predicciones_lineal = modelo_lineal.predict(X)

predicciones_lineal[:10]
# Out:
# array([1862694.64108108, 1871205.44506479, 1879716.2490485 ,
#        1888227.05303221, 1896737.85701592, 1905248.66099963,
#        1913759.46498334, 1922270.26896705, 1930781.07295076,
#        1939291.87693447])

# %% [markdown]
# ## 16. Realizar proyecciones hasta 2100
#
# Creamos los años para los que queremos generar **nuestras propias proyecciones**.

# %%
anios_futuros = np.arange(2024, 2101).reshape(-1, 1)

print("Forma:", anios_futuros.shape)
anios_futuros[:10]
# Out:
# Forma: (77, 1)
# array([[2024],
#        [2025],
#        [2026],
#        [2027],
#        [2028],
#        [2029],
#        [2030],
#        [2031],
#        [2032],
#        [2033]])

# %% [markdown]
# > **Detalle técnico:** entrenamos el modelo con `X`, que es un `DataFrame` con una columna llamada `Year`. Scikit-learn recuerda ese nombre, así que para predecir también debemos entregarle un `DataFrame` con una columna `Year`. Si le pasáramos un arreglo de NumPy "a secas" mostraría una advertencia (*UserWarning: X does not have valid feature names*). Por eso convertimos los años futuros a `DataFrame`.

# %%
X_futuro = pd.DataFrame(anios_futuros, columns=["Year"])

X_futuro.head()
# Out:
#    Year
# 0  2024
# 1  2025
# 2  2026
# 3  2027
# 4  2028

# %%
predicciones_lineal_futuras = modelo_lineal.predict(X_futuro)

# %%
print(predicciones_lineal_futuras[:10])
# Out:
# [2492494.1358756  2501004.93985931 2509515.74384302 2518026.54782673
#  2526537.35181044 2535048.15579415 2543558.95977786 2552069.76376157
#  2560580.56774528 2569091.37172899]

# %% [markdown]
# # PARTE 8. Visualizar la regresión lineal
#
# ## 17. Comparar datos históricos y predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_historico["Year"],
    df_historico["births"],
    label="Datos históricos",
    alpha=0.6
)

# Ajuste del modelo sobre los años históricos
plt.plot(
    df_historico["Year"],
    predicciones_lineal,
    color="tab:orange",
    label="Regresión lineal (ajuste histórico)"
)

# Proyección hacia el futuro
plt.plot(
    anios_futuros.flatten(),
    predicciones_lineal_futuras,
    color="tab:orange",
    linestyle="--",
    label="Regresión lineal (proyección)"
)

plt.title("Proyección de nacimientos – Regresión lineal")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Analiza cómo continúa la tendencia histórica cuando utilizamos una **función lineal**. ¿Qué pasa con los valores hacia el año 2100? Como el modelo no es capaz de seguir la curva ni de doblarse para seguir los datos, es probable que la información este incompleta o ignore datos.

# %% [markdown]
# # PARTE 9. Modelo 2 – Regresión polinomial
#
# ## 18. Crear variables polinomiales
#
# La regresión lineal solamente puede representar una relación **lineal** entre las variables. Ahora construiremos variables polinomiales para permitir **curvas**. Utilizaremos un polinomio de **grado 2**:
#
# $$y = a \cdot x^2 + b \cdot x + c$$

# %%
poly = PolynomialFeatures(
    degree=2,
    include_bias=False
)

# %% [markdown]
# Transformamos `X`:

# %%
X_poly = poly.fit_transform(X)

X_poly[:5]
# Out:
# array([[1.950000e+03, 3.802500e+06],
#        [1.951000e+03, 3.806401e+06],
#        [1.952000e+03, 3.810304e+06],
#        [1.953000e+03, 3.814209e+06],
#        [1.954000e+03, 3.818116e+06]])

# %% [markdown]
# Observa que ahora cada año tiene **dos columnas**: el año (`x`) y el año al cuadrado (`x²`).
#
# ## 19. Crear y entrenar el modelo polinomial
#
# Seguimos utilizando `LinearRegression`; lo único que cambió son las **variables de entrada**.

# %%
modelo_polinomial = LinearRegression()

modelo_polinomial.fit(
    X_poly,
    y_nacimientos
)
# Out:
# LinearRegression()

# %% [markdown]
# ## 20. Generar predicciones históricas

# %%
predicciones_polinomiales = modelo_polinomial.predict(
    X_poly
)

# %% [markdown]
# ## 21. Generar proyecciones hasta 2100
#
# Transformamos los años futuros utilizando **el mismo objeto `poly`** con el que transformamos los datos de entrenamiento.

# %%
anios_futuros_poly = poly.transform(
    X_futuro
)

predicciones_polinomiales_futuras = modelo_polinomial.predict(
    anios_futuros_poly
)

# %% [markdown]
# # PARTE 10. Visualizar la regresión polinomial
#
# ## 22. Graficar las predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_historico["Year"],
    df_historico["births"],
    label="Datos históricos",
    alpha=0.6
)

plt.plot(
    df_historico["Year"],
    predicciones_polinomiales,
    color="tab:green",
    label="Regresión polinomial (ajuste histórico)"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_polinomiales_futuras,
    color="tab:green",
    linestyle="--",
    label="Regresión polinomial (proyección)"
)

plt.title("Proyección de nacimientos – Regresión polinomial")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Compara el comportamiento de esta gráfica con el modelo de regresión lineal. ¿Se ajusta mejor a los datos históricos? ¿Qué ocurre con la proyección hacia el año 2100? ¿Los valores que predice tienen sentido para un número de nacimientos?
#
# 1- Sí, se ajusta mucho mejor ya que le permite adaptarse a la curva del registro de los datos histróicos, capturando tanto la súbida inicial como la caída posterior que se presenta.
# 2- Como se cae en declive durante esos registros, se puede asumir que la caída continuara del mismo modo en las siguientes proyecciones.
# 3- No, porque en algún momento tendrá que bajar de cero y eso significaría que predice nacimientos negativos, cosa que no tiene sentido.

# %% [markdown]
# # PARTE 11. Modelo 3 – Random Forest
#
# ## 23. Crear el modelo
#
# Un **Random Forest** está formado por muchos árboles de decisión. Utilizaremos `RandomForestRegressor`.

# %%
modelo_rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %% [markdown]
# ## 24. Entrenar el modelo

# %%
modelo_rf.fit(
    X,
    y_nacimientos
)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## 25. Generar predicciones históricas

# %%
predicciones_rf = modelo_rf.predict(X)

# %% [markdown]
# ## 26. Generar proyecciones futuras

# %%
predicciones_rf_futuras = modelo_rf.predict(
    X_futuro
)

# %% [markdown]
# # PARTE 12. Visualizar Random Forest
#
# ## 27. Graficar las predicciones

# %%
plt.figure(figsize=(12, 6))

plt.scatter(
    df_historico["Year"],
    df_historico["births"],
    label="Datos históricos",
    alpha=0.6
)

plt.plot(
    df_historico["Year"],
    predicciones_rf,
    color="tab:red",
    label="Random Forest (ajuste histórico)"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_rf_futuras,
    color="tab:red",
    linestyle="--",
    label="Random Forest (proyección)"
)

plt.title("Proyección de nacimientos – Random Forest")
plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Observación
#
# Fíjate en dos cosas: (1) qué tan bien sigue el modelo los datos históricos y (2) qué sucede con la línea después de 2023. ¿Continúa la tendencia? ¿Por qué crees que sucede esto? Investiga.

# %% [markdown]
# # PARTE 13. Comparar los tres modelos
#
# ## 28. Graficar los tres modelos
#
# Construimos una gráfica que permita comparar directamente los resultados.
#
# > Si la regresión polinomial genera valores muy extremos y no permite ver bien las demás curvas, puedes limitar el eje vertical agregando, por ejemplo, `plt.ylim(0, 3_500_000)` antes de `plt.show()`.

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    df_historico["Year"],
    df_historico["births"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_lineal_futuras,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_polinomiales_futuras,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_rf_futuras,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar nacimientos en México"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # PARTE 14. Repetir el proceso para defunciones
#
# Hasta este momento construimos modelos para predecir **nacimientos**. Ahora repetiremos el mismo proceso para **defunciones**.
#
# ## 29. Preparar la variable objetivo
#
# La variable predictora sigue siendo `X` (el año). Solo cambia la variable objetivo:

# %%
y_defunciones = df_historico["deaths"]

# %% [markdown]
# ## 30. Regresión lineal para defunciones

# %%
modelo_lineal_deaths = LinearRegression()

modelo_lineal_deaths.fit(
    X,
    y_defunciones
)

predicciones_lineal_deaths = modelo_lineal_deaths.predict(
    X_futuro
)

# %% [markdown]
# ## 31. Regresión polinomial para defunciones
#
# Utilizamos nuevamente las variables construidas con `PolynomialFeatures` (`X_poly` y `anios_futuros_poly`).

# %%
modelo_polinomial_deaths = LinearRegression()

modelo_polinomial_deaths.fit(
    X_poly,
    y_defunciones
)

predicciones_polinomiales_deaths = modelo_polinomial_deaths.predict(
    anios_futuros_poly
)

# %% [markdown]
# ## 32. Random Forest para defunciones

# %%
modelo_rf_deaths = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

modelo_rf_deaths.fit(
    X,
    y_defunciones
)

predicciones_rf_deaths = modelo_rf_deaths.predict(
    X_futuro
)

# %% [markdown]
# # PARTE 15. Comparar las predicciones de defunciones
#
# ## 33. Visualizar los tres modelos

# %%
plt.figure(figsize=(14, 7))

plt.scatter(
    df_historico["Year"],
    df_historico["deaths"],
    label="Datos históricos",
    alpha=0.5
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_lineal_deaths,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_polinomiales_deaths,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_rf_deaths,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Comparación de modelos para proyectar defunciones en México"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # PARTE 16. Comparar nuestros modelos con las proyecciones de OWID
#
# Finalmente, agregamos a las gráficas las **proyecciones proporcionadas por OWID** (las de la ONU, escenario medio). Estas proyecciones no se obtienen ajustando una recta a la serie histórica: se construyen con modelos demográficos que consideran fecundidad, mortalidad y estructura por edad de la población.
#
# ## 34. Nacimientos: ML vs OWID

# %%
plt.figure(figsize=(14, 7))

plt.plot(
    df_proyectado["Year"],
    df_proyectado["births"],
    color="black",
    linewidth=2.5,
    label="Proyección OWID"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_lineal_futuras,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_polinomiales_futuras,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_rf_futuras,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Proyecciones de nacimientos: ML vs OWID"
)

plt.xlabel("Año")
plt.ylabel("Nacimientos")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 35. Defunciones: ML vs OWID
#
# Repetimos el ejercicio para defunciones.

# %%
plt.figure(figsize=(14, 7))

plt.plot(
    df_proyectado["Year"],
    df_proyectado["deaths"],
    color="black",
    linewidth=2.5,
    label="Proyección OWID"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_lineal_deaths,
    color="tab:orange",
    label="Regresión lineal"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_polinomiales_deaths,
    color="tab:green",
    label="Regresión polinomial"
)

plt.plot(
    anios_futuros.flatten(),
    predicciones_rf_deaths,
    color="tab:red",
    label="Random Forest"
)

plt.title(
    "Proyecciones de defunciones: ML vs OWID"
)

plt.xlabel("Año")
plt.ylabel("Defunciones")

plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 36. Resumen numérico (opcional)
#
# A veces es útil ver los números y no solo la gráfica. Esta tabla muestra lo que predice cada modelo para algunos años seleccionados:

# %%
anios_tabla = [2030, 2050, 2075, 2100]
indice = anios_futuros.flatten()


def construir_tabla(owid, lineal, polinomial, rf):
    tabla = pd.DataFrame(
        {
            "OWID": owid.set_index("Year").reindex(indice).to_numpy().ravel(),
            "Regresión lineal": lineal,
            "Regresión polinomial": polinomial,
            "Random Forest": rf,
        },
        index=indice
    )
    tabla.index.name = "Año"
    return tabla.loc[anios_tabla]


print("NACIMIENTOS")
display(
    construir_tabla(
        df_proyectado[["Year", "births"]],
        predicciones_lineal_futuras,
        predicciones_polinomiales_futuras,
        predicciones_rf_futuras
    ).style.format("{:,.0f}")
)

print("DEFUNCIONES")
display(
    construir_tabla(
        df_proyectado[["Year", "deaths"]],
        predicciones_lineal_deaths,
        predicciones_polinomiales_deaths,
        predicciones_rf_deaths
    ).style.format("{:,.0f}")
)
# Out:
# NACIMIENTOS
# <style type="text/css">
# </style>
# <table id="T_1df09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1df09_level0_col0" class="col_heading level0 col0" >OWID</th>
#       <th id="T_1df09_level0_col1" class="col_heading level0 col1" >Regresión lineal</th>
#       <th id="T_1df09_level0_col2" class="col_heading level0 col2" >Regresión polinomial</th>
#       <th id="T_1df09_level0_col3" class="col_heading level0 col3" >Random Forest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Año</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1df09_level0_row0" class="row_heading level0 row0" >2030</th>
#       <td id="T_1df09_row0_col0" class="data row0 col0" >1,934,285</td>
# ...

# %% [markdown]
# # PARTE 17. Reflexión
#
# Responde las siguientes preguntas en esta misma celda (haz doble clic para editarla).
#
# ### 1.
# ¿Qué diferencia observaste entre la regresión lineal, la regresión polinomial y Random Forest?
#
# *Que permiten adaptarse mejor para la proyeccion de los datos, por ejemplo: la polinomial permite curvearse para seguir la forma real de los datos y permite una mejor captura de los mismos, mientras que random por ejemplo agrupa los datos y valores por bloques.*
#
# ### 2.
# ¿Por qué los tres modelos generan predicciones diferentes si utilizaron los mismos datos históricos?
#
# *Porque cada algoritmo tiene un comportamiento matemático diferente, analizando y trabajando con los datos de modo diferente.*
#
# ### 3.
# ¿Qué modelo produjo una tendencia más cercana visualmente a las proyecciones de OWID?
#
# *La regresión polinomial, ya que al permitir una curvatura se apega de maenra real a la captura y registro de los datos.*
#
# ### 4.
# ¿El modelo que visualmente parece acercarse más a las proyecciones de OWID necesariamente es el mejor modelo? Explica.
#
# *Realmente ninguna es el mejor modelo, por ejemplo la polinomial en algun momento debera cruzar el eje cero proponiendo datos completamente falsos o imposibles y erdiendo sentido alguno.*
#
# ### 5.
# ¿Qué comportamiento observaste en las predicciones de Random Forest para los años posteriores a 2023?
#
# *Que se convierte en una línea recta completa debido a que no es capaz de seguir tendencias.*
#
# ### 6.
# ¿Por qué debemos tener cuidado al utilizar un modelo entrenado con datos históricos para realizar predicciones hasta el año 2100?
#
# *Porque se asume de alguna manera que el cambio, flujo y variabilidad será constante durante el resto de los años, siendo algo simplemente improbable.*

# %% [markdown]
# # PARTE 18. Conceptos clave
#
# Al finalizar la práctica, debes poder identificar:
#
# | Concepto | Significado |
# |---|---|
# | **Variable predictora** | Variable utilizada por el modelo para generar una predicción |
# | **Variable objetivo** | Variable que queremos predecir |
# | **Entrenamiento** | Proceso mediante el cual el modelo aprende a partir de los datos |
# | **Predicción** | Resultado generado por el modelo |
# | **Regresión lineal** | Modelo que representa una relación lineal |
# | **Regresión polinomial** | Extensión que permite representar relaciones curvas |
# | **Random Forest** | Modelo basado en múltiples árboles de decisión |
# | **Extrapolación** | Generación de predicciones fuera del rango de datos utilizados para entrenar el modelo |
#
# > **Importante:** En esta práctica solamente hemos **construido y utilizado** los modelos. En la siguiente práctica aprenderemos a **evaluar su desempeño mediante métricas**, para determinar qué tan bien están realizando sus predicciones.

# %%
# EJERCICIO 1: EXTRAER CHINA


df_china = df[df["Entity"] == "China"].copy()
df_hist_china = df_china[df_china["Year"] <= 2023]

X_china = df_hist_china[["Year"]]
y_nac_china = df_hist_china["births"]
y_def_china = df_hist_china["deaths"]

anios_fut_china = np.arange(2024, 2101).reshape(-1, 1)
X_fut_china = pd.DataFrame(anios_fut_china, columns=["Year"])

mod_lin_nac_ch = LinearRegression().fit(X_china, y_nac_china)
pred_lin_nac_ch = mod_lin_nac_ch.predict(X_china)
pred_lin_fut_nac_ch = mod_lin_nac_ch.predict(X_fut_china)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_nac_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_lin_nac_ch, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_lin_fut_nac_ch, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de nacimientos en China – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

poly_ch = PolynomialFeatures(degree=2, include_bias=False)
X_poly_ch = poly_ch.fit_transform(X_china)
X_fut_poly_ch = poly_ch.transform(X_fut_china)

mod_poly_nac_ch = LinearRegression().fit(X_poly_ch, y_nac_china)
pred_poly_nac_ch = mod_poly_nac_ch.predict(X_poly_ch)
pred_poly_fut_nac_ch = mod_poly_nac_ch.predict(X_fut_poly_ch)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_nac_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_poly_nac_ch, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_poly_fut_nac_ch, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de nacimientos en China – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_nac_ch = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_china, y_nac_china)
pred_rf_nac_ch = mod_rf_nac_ch.predict(X_china)
pred_rf_fut_nac_ch = mod_rf_nac_ch.predict(X_fut_china)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_nac_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_rf_nac_ch, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_rf_fut_nac_ch, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de nacimientos en China – Random Forest")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_nac_china, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_china.flatten(), pred_lin_fut_nac_ch, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_china.flatten(), pred_poly_fut_nac_ch, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_china.flatten(), pred_rf_fut_nac_ch, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Nacimientos en China")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_lin_def_ch = LinearRegression().fit(X_china, y_def_china)
pred_lin_def_ch = mod_lin_def_ch.predict(X_china)
pred_lin_fut_def_ch = mod_lin_def_ch.predict(X_fut_china)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_def_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_lin_def_ch, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_lin_fut_def_ch, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de defunciones en China – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_poly_def_ch = LinearRegression().fit(X_poly_ch, y_def_china)
pred_poly_def_ch = mod_poly_def_ch.predict(X_poly_ch)
pred_poly_fut_def_ch = mod_poly_def_ch.predict(X_fut_poly_ch)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_def_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_poly_def_ch, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_poly_fut_def_ch, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de defunciones en China – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_def_ch = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_china, y_def_china)
pred_rf_def_ch = mod_rf_def_ch.predict(X_china)
pred_rf_fut_def_ch = mod_rf_def_ch.predict(X_fut_china)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_def_china, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_china["Year"], pred_rf_def_ch, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_china.flatten(), pred_rf_fut_def_ch, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de defunciones en China – Random Forest")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_china["Year"], y_def_china, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_china.flatten(), pred_lin_fut_def_ch, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_china.flatten(), pred_poly_fut_def_ch, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_china.flatten(), pred_rf_fut_def_ch, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Defunciones en China")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %%
# EJERCICIO 2: EXTRAER MÉXICO A PARTIR DE 1980

df_mex80 = df[(df["Entity"] == "Mexico") & (df["Year"] >= 1980)].copy()
df_hist_mex80 = df_mex80[df_mex80["Year"] <= 2023]

X_mex80 = df_hist_mex80[["Year"]]
y_nac_mex80 = df_hist_mex80["births"]
y_def_mex80 = df_hist_mex80["deaths"]

anios_fut_mex80 = np.arange(2024, 2101).reshape(-1, 1)
X_fut_mex80 = pd.DataFrame(anios_fut_mex80, columns=["Year"])

poly_mex80 = PolynomialFeatures(degree=2, include_bias=False)
X_poly_mex80 = poly_mex80.fit_transform(X_mex80)
X_fut_poly_mex80 = poly_mex80.transform(X_fut_mex80)

mod_lin_nac_m80 = LinearRegression().fit(X_mex80, y_nac_mex80)
pred_lin_nac_m80 = mod_lin_nac_m80.predict(X_mex80)
pred_lin_fut_nac_m80 = mod_lin_nac_m80.predict(X_fut_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_nac_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_lin_nac_m80, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_lin_fut_nac_m80, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de nacimientos en México desde 1980 – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_poly_nac_m80 = LinearRegression().fit(X_poly_mex80, y_nac_mex80)
pred_poly_nac_m80 = mod_poly_nac_m80.predict(X_poly_mex80)
pred_poly_fut_nac_m80 = mod_poly_nac_m80.predict(X_fut_poly_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_nac_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_poly_nac_m80, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_poly_fut_nac_m80, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de nacimientos en México desde 1980 – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_nac_m80 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_mex80, y_nac_mex80)
pred_rf_nac_m80 = mod_rf_nac_m80.predict(X_mex80)
pred_rf_fut_nac_m80 = mod_rf_nac_m80.predict(X_fut_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_nac_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_rf_nac_m80, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_rf_fut_nac_m80, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de nacimientos en México desde 1980 – Random Forest")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_nac_mex80, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_mex80.flatten(), pred_lin_fut_nac_m80, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_mex80.flatten(), pred_poly_fut_nac_m80, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_mex80.flatten(), pred_rf_fut_nac_m80, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Nacimientos en México desde 1980")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_lin_def_m80 = LinearRegression().fit(X_mex80, y_def_mex80)
pred_lin_def_m80 = mod_lin_def_m80.predict(X_mex80)
pred_lin_fut_def_m80 = mod_lin_def_m80.predict(X_fut_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_def_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_lin_def_m80, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_lin_fut_def_m80, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de defunciones en México desde 1980 – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_poly_def_m80 = LinearRegression().fit(X_poly_mex80, y_def_mex80)
pred_poly_def_m80 = mod_poly_def_m80.predict(X_poly_mex80)
pred_poly_fut_def_m80 = mod_poly_def_m80.predict(X_fut_poly_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_def_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_poly_def_m80, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_poly_fut_def_m80, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de defunciones en México desde 1980 – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_def_m80 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_mex80, y_def_mex80)
pred_rf_def_m80 = mod_rf_def_m80.predict(X_mex80)
pred_rf_fut_def_m80 = mod_rf_def_m80.predict(X_fut_mex80)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_def_mex80, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex80["Year"], pred_rf_def_m80, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_mex80.flatten(), pred_rf_fut_def_m80, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de defunciones en México desde 1980 – Random Forest")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex80["Year"], y_def_mex80, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_mex80.flatten(), pred_lin_fut_def_m80, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_mex80.flatten(), pred_poly_fut_def_m80, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_mex80.flatten(), pred_rf_fut_def_m80, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Defunciones en México desde 1980")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

# %%
# EJERCICIO 3: EXTRAER MÉXICO A PARTIR DE 2000

df_mex00 = df[(df["Entity"] == "Mexico") & (df["Year"] >= 2000)].copy()
df_hist_mex00 = df_mex00[df_mex00["Year"] <= 2023]

X_mex00 = df_hist_mex00[["Year"]]
y_nac_mex00 = df_hist_mex00["births"]
y_def_mex00 = df_hist_mex00["deaths"]

anios_fut_mex00 = np.arange(2024, 2101).reshape(-1, 1)
X_fut_mex00 = pd.DataFrame(anios_fut_mex00, columns=["Year"])

poly_mex00 = PolynomialFeatures(degree=2, include_bias=False)
X_poly_mex00 = poly_mex00.fit_transform(X_mex00)
X_fut_poly_mex00 = poly_mex00.transform(X_fut_mex00)

mod_lin_nac_m00 = LinearRegression().fit(X_mex00, y_nac_mex00)
pred_lin_nac_m00 = mod_lin_nac_m00.predict(X_mex00)
pred_lin_fut_nac_m00 = mod_lin_nac_m00.predict(X_fut_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_nac_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_lin_nac_m00, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_lin_fut_nac_m00, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de nacimientos en México desde 2000 – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_poly_nac_m00 = LinearRegression().fit(X_poly_mex00, y_nac_mex00)
pred_poly_nac_m00 = mod_poly_nac_m00.predict(X_poly_mex00)
pred_poly_fut_nac_m00 = mod_poly_nac_m00.predict(X_fut_poly_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_nac_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_poly_nac_m00, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_poly_fut_nac_m00, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de nacimientos en México desde 2000 – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_nac_m00 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_mex00, y_nac_mex00)
pred_rf_nac_m00 = mod_rf_nac_m00.predict(X_mex00)
pred_rf_fut_nac_m00 = mod_rf_nac_m00.predict(X_fut_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_nac_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_rf_nac_m00, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_rf_fut_nac_m00, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de nacimientos en México desde 2000 – Random Forest")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_nac_mex00, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_mex00.flatten(), pred_lin_fut_nac_m00, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_mex00.flatten(), pred_poly_fut_nac_m00, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_mex00.flatten(), pred_rf_fut_nac_m00, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Nacimientos en México desde 2000")
plt.xlabel("Año")
plt.ylabel("Nacimientos")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_lin_def_m00 = LinearRegression().fit(X_mex00, y_def_mex00)
pred_lin_def_m00 = mod_lin_def_m00.predict(X_mex00)
pred_lin_fut_def_m00 = mod_lin_def_m00.predict(X_fut_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_def_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_lin_def_m00, color="tab:orange", label="Regresión lineal (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_lin_fut_def_m00, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.title("Proyección de defunciones en México desde 2000 – Regresión Lineal")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_poly_def_m00 = LinearRegression().fit(X_poly_mex00, y_def_mex00)
pred_poly_def_m00 = mod_poly_def_m00.predict(X_poly_mex00)
pred_poly_fut_def_m00 = mod_poly_def_m00.predict(X_fut_poly_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_def_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_poly_def_m00, color="tab:green", label="Regresión polinomial (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_poly_fut_def_m00, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.title("Proyección de defunciones en México desde 2000 – Regresión Polinomial")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

mod_rf_def_m00 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X_mex00, y_def_mex00)
pred_rf_def_m00 = mod_rf_def_m00.predict(X_mex00)
pred_rf_fut_def_m00 = mod_rf_def_m00.predict(X_fut_mex00)

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_def_mex00, label="Datos históricos", alpha=0.6)
plt.plot(df_hist_mex00["Year"], pred_rf_def_m00, color="tab:red", label="Random Forest (ajuste histórico)")
plt.plot(anios_fut_mex00.flatten(), pred_rf_fut_def_m00, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Proyección de defunciones en México desde 2000 – Random Forest")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(df_hist_mex00["Year"], y_def_mex00, label="Datos históricos", alpha=0.6)
plt.plot(anios_fut_mex00.flatten(), pred_lin_fut_def_m00, color="tab:orange", linestyle="--", label="Regresión lineal (proyección)")
plt.plot(anios_fut_mex00.flatten(), pred_poly_fut_def_m00, color="tab:green", linestyle="--", label="Regresión polinomial (proyección)")
plt.plot(anios_fut_mex00.flatten(), pred_rf_fut_def_m00, color="tab:red", linestyle="--", label="Random Forest (proyección)")
plt.title("Comparación de Modelos: Defunciones en México desde 2000")
plt.xlabel("Año")
plt.ylabel("Defunciones")
plt.ticklabel_format(style="plain", axis="y", useOffset=False)
plt.legend()
plt.grid()
plt.show()
